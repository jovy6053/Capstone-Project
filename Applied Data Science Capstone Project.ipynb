# %% [markdown]
# # Applied Data Science Capstone Project

# %% [markdown]
# ## This notebook is intended for use in Applied Data Science Capstone Project

# %%
# Applied Data Science Capstone Project
## This notebook is intented for use in Applied Data Science Project
bolded_text1 = "\033[1m" + "Applied Data Science Capstone Project" + "\033[0m"
bolded_text2 = "\033[1m" + "This notebook is intended for use in Applied Data Science Capstone Project" + "\033[0m"
print(bolded_text1, '\n', bolded_text2)
# Out:
# Applied Data Science Capstone Project
#  This notebook is intended for use in Applied Data Science Capstone Project

# %%
# Import Libraries
import pandas as pd
import numpy as np

print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
